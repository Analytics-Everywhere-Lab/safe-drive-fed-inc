# %%
from ultralytics import YOLO
import os
import yaml
import json

# %%
for root, dirs, files in os.walk('../'):
    for file in files:
        if file == 'labels.cache':
            os.remove(os.path.join(root, file))

# %% [markdown]
# # Server

# %%
device_folders = ['server']
# device_folders = ['server', 'client1', 'client2', 'client3', 'client4']
rounds = ['round_1', 'round_2', 'round_3', 'round_4', 'round_5']

# Function to update the test.yaml file
def update_yaml(device_folder, round_name):
    yaml_path = f'{round_name}.yaml'
    with open(yaml_path, 'r') as file:
        data = yaml.safe_load(file)
    
    data['test'] = f'../{device_folder}/incremental_dataset/{round_name}/test/images'
    data['train'] = f'../{device_folder}/incremental_dataset/{round_name}/train/images'
    data['val'] = f'../{device_folder}/incremental_dataset/{round_name}/val/images'
    
    with open(yaml_path, 'w') as file:
        yaml.safe_dump(data, file)

# Iterate over each device and round
results = {}
for round_name in rounds:
    # Update the test.yaml file
    update_yaml('server', round_name)
    
    # Load the last.pt model
    model_path = f'../runs/detect/{round_name}/weights/last.pt'
    model = YOLO(model_path)
    
    # Print the results
    print(f"Results for Server - {round_name}:")
    # Test the model using the updated YAML file
    metrics = model.val(data=f'{round_name}.yaml', split='test')
    incr_results = {
        'map50': float(f'{metrics.box.map50:.4f}'),
        'precision': float(f'{metrics.box.mp:.4f}'),
        'recall': float(f'{metrics.box.mr:.4f}'),
    }
    results[round_name] = incr_results
    # Dump the results into a JSON file
results_path = f'server.json'
with open(results_path, 'w') as json_file:
    json.dump(results, json_file)
    # print(results)
# Out:
# Results for Server - round_1:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_1/test/labels... 45 images, 0 backgrounds, 0 corrupt: 100%|██████████| 45/45 [00:00<00:00, 4570.84it/s]
# val: New cache created: /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_1/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  4.38it/s]
#                    all         45         53      0.939      0.998      0.986       0.58
#            no_seatbelt         32         32      0.941      0.996      0.982      0.709
#                 mobile         21         21      0.936          1      0.991      0.452
# Speed: 0.8ms preprocess, 1.6ms inference, 0.1ms loss, 2.6ms postprocess per image
# Results saved to runs/detect/val86
# Results for Server - round_2:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_2/test/labels... 52 images, 0 backgrounds, 0 corrupt: 100%|██████████| 52/52 [00:00<00:00, 2728.24it/s]
# val: New cache created: /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_2/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  4.97it/s]
#                    all         52         65      0.962      0.959      0.971      0.648
#            no_seatbelt         28         28      0.946      0.964      0.969      0.799
#                 mobile         24         24      0.939          1      0.993      0.533
#            inattentive         13         13          1      0.913      0.951      0.611
# Speed: 1.4ms preprocess, 3.4ms inference, 0.1ms loss, 4.0ms postprocess per image
# Results saved to runs/detect/val87
# Results for Server - round_3:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_3/test/labels... 76 images, 0 backgrounds, 0 corrupt: 100%|██████████| 76/76 [00:00<00:00, 1825.46it/s]
# val: New cache created: /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_3/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  5.34it/s]
#                    all         76        108      0.933      0.937      0.946      0.692
#            no_seatbelt         25         25       0.86      0.982      0.947      0.751
#                 mobile         19         19      0.922          1      0.995      0.646
#            inattentive         17         17      0.996      0.882        0.9      0.679
#               seatbelt         47         47      0.954      0.886      0.941      0.692
# Speed: 1.5ms preprocess, 1.7ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to runs/detect/val88
# Results for Server - round_4:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_4/test/labels... 76 images, 0 backgrounds, 0 corrupt: 100%|██████████| 76/76 [00:00<00:00, 2749.91it/s]
# val: New cache created: /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_4/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  5.34it/s]
#                    all         76        146      0.938      0.949      0.962      0.705
#            no_seatbelt         31         31      0.969          1      0.991      0.847
#                 mobile         22         22      0.923          1      0.995      0.654
#            inattentive         19         20      0.947       0.89      0.923      0.638
#               seatbelt         43         43      0.933      0.953      0.979       0.75
#             drowsiness         30         30      0.917        0.9      0.924      0.635
# Speed: 0.9ms preprocess, 2.7ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to runs/detect/val89
# Results for Server - round_5:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_5/test/labels... 77 images, 0 backgrounds, 0 corrupt: 100%|██████████| 77/77 [00:00<00:00, 3294.01it/s]
# val: New cache created: /home/u55hy/Documents/Research/safe-drive-fed-inc/server/incremental_dataset/round_5/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:00<00:00,  5.30it/s]
#                    all         77        147      0.932      0.964      0.951      0.646
#            no_seatbelt         34         34      0.971          1      0.993      0.823
#                 mobile         18         18      0.872      0.944      0.888      0.559
#            inattentive          8          8      0.968          1      0.995      0.727
#               seatbelt         41         41      0.973      0.976      0.981      0.727
#             drowsiness         33         33      0.886       0.94      0.962      0.683
#               drinking         13         13      0.921      0.923      0.885      0.355
# Speed: 0.9ms preprocess, 3.2ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to runs/detect/val90

# %% [markdown]
# # Clients

# %%
device_folders = ['client1', 'client2', 'client3', 'client4']
incr_rounds = ['round_1', 'round_2', 'round_3', 'round_4', 'round_5']

# Function to update the test.yaml file
def update_yaml(device_folder, round_name):
    yaml_path = f'{round_name}.yaml'
    with open(yaml_path, 'r') as file:
        data = yaml.safe_load(file)
    
    data['test'] = f'../{device_folder}/incremental_dataset/{round_name}/test/images'
    data['train'] = f'../{device_folder}/incremental_dataset/{round_name}/train/images'
    data['val'] = f'../{device_folder}/incremental_dataset/{round_name}/val/images'
    
    with open(yaml_path, 'w') as file:
        yaml.safe_dump(data, file)



# Iterate over each device and round
for device_folder in device_folders:
    results = {}
    for round_name in incr_rounds:
        # Update the test.yaml file
        update_yaml(device_folder, round_name)
        
        # Load the last.pt model
        fl_model_path = f'../runs/detect/{round_name}_fed12345_fine_tune_{device_folder}/weights/last.pt'
        fl_model = YOLO(fl_model_path)
        
        # Load the last.pt model
        model_path = f'../runs/detect/{round_name}_fine_tune_{device_folder}/weights/last.pt'
        model = YOLO(model_path)
        
        # Print the results
        print(f"Results for {device_folder} - {round_name}:")
        # Test the model using the updated YAML file
        metrics = fl_model.val(data=f'{round_name}.yaml', split='test')
        fl_results = {
            'map50': float(f'{metrics.box.map50:.4f}'),
            'precision': float(f'{metrics.box.mp:.4f}'),
            'recall': float(f'{metrics.box.mr:.4f}'),
        }
        
        # # Dump the results into a JSON file
        # results_path = f'{device_folder}_{round_name}_FL.json'
        # with open(results_path, 'w') as json_file:
        #     json.dump(results, json_file)
        
        metrics = model.val(data=f'{round_name}.yaml', split='test')
        no_fl_results = {
            'map50': float(f'{metrics.box.map50:.4f}'),
            'precision': float(f'{metrics.box.mp:.4f}'),
            'recall': float(f'{metrics.box.mr:.4f}'),
        }
        
        results[round_name] = {
            'No_FL': no_fl_results,
            'FL': fl_results
        }
    # Dump the results into a JSON file
    results_path = f'{device_folder}.json'
    with open(results_path, 'w') as json_file:
        json.dump(results, json_file)
# Out:
# Results for client1 - round_1:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_1/test/labels.cache... 21 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21/21 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.61it/s]
#                    all         21         25      0.888      0.952      0.928      0.509
#            no_seatbelt         14         14          1      0.994      0.995       0.66
#                 mobile         11         11      0.777      0.909      0.862      0.358
# Speed: 0.7ms preprocess, 8.5ms inference, 0.0ms loss, 3.3ms postprocess per image
# Results saved to runs/detect/val131
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_1/test/labels.cache... 21 images, 0 backgrounds, 0 corrupt: 100%|██████████| 21/21 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  7.36it/s]
#                    all         21         25       0.95       0.95      0.933      0.527
#            no_seatbelt         14         14          1      0.991      0.995      0.684
#                 mobile         11         11        0.9      0.909       0.87       0.37
# Speed: 1.0ms preprocess, 4.7ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val132
# Results for client1 - round_2:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_2/test/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.97it/s]
#                    all         26         31      0.938      0.877      0.932       0.52
#            no_seatbelt         12         12      0.941      0.917      0.941      0.601
#                 mobile         13         13      0.903      0.715      0.861      0.329
#            inattentive          6          6      0.972          1      0.995      0.631
# Speed: 1.0ms preprocess, 6.0ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val133
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_2/test/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  6.90it/s]
#                    all         26         31      0.941      0.921      0.957      0.558
#            no_seatbelt         12         12      0.894      0.917      0.938      0.601
#                 mobile         13         13      0.944      0.846      0.939      0.401
#            inattentive          6          6      0.985          1      0.995      0.673
# Speed: 0.6ms preprocess, 2.6ms inference, 0.0ms loss, 1.5ms postprocess per image
# Results saved to runs/detect/val134
# Results for client1 - round_3:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_3/test/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.99it/s]
#                    all         40         55      0.909       0.95      0.981      0.546
#            no_seatbelt         13         13      0.898          1      0.995      0.697
#                 mobile         11         11       0.91      0.926       0.98       0.47
#            inattentive          8          8      0.858      0.875      0.955       0.52
#               seatbelt         23         23      0.968          1      0.995      0.497
# Speed: 0.8ms preprocess, 4.1ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val135
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_3/test/labels.cache... 40 images, 0 backgrounds, 0 corrupt: 100%|██████████| 40/40 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  7.09it/s]
#                    all         40         55      0.931      0.969      0.972      0.561
#            no_seatbelt         13         13      0.922          1      0.995      0.709
#                 mobile         11         11      0.967          1      0.995      0.495
#            inattentive          8          8      0.856      0.875      0.902      0.502
#               seatbelt         23         23      0.979          1      0.995      0.539
# Speed: 0.7ms preprocess, 1.6ms inference, 0.0ms loss, 2.1ms postprocess per image
# Results saved to runs/detect/val136
# Results for client1 - round_4:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_4/test/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.20it/s]
#                    all         42         72      0.986      0.964      0.995      0.574
#            no_seatbelt         10         10      0.961          1      0.995      0.748
#                 mobile          9          9      0.969          1      0.995      0.356
#            inattentive          9          9          1          1      0.995      0.587
#               seatbelt         27         27          1      0.978      0.995      0.613
#             drowsiness         17         17          1      0.842      0.995      0.565
# Speed: 0.8ms preprocess, 2.2ms inference, 0.0ms loss, 3.5ms postprocess per image
# Results saved to runs/detect/val137
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_4/test/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.30it/s]
#                    all         42         72      0.985      0.947      0.989      0.575
#            no_seatbelt         10         10      0.961          1      0.995      0.751
#                 mobile          9          9      0.992          1      0.995      0.385
#            inattentive          9          9      0.972      0.889      0.968      0.573
#               seatbelt         27         27          1      0.997      0.995      0.576
#             drowsiness         17         17          1      0.847      0.995      0.589
# Speed: 0.9ms preprocess, 2.3ms inference, 0.0ms loss, 2.4ms postprocess per image
# Results saved to runs/detect/val138
# Results for client1 - round_5:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_5/test/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.83it/s]
#                    all         42         72      0.873      0.944      0.951      0.535
#            no_seatbelt         13         13      0.857      0.923       0.95      0.778
#                 mobile         10         10          1      0.965      0.995      0.418
#            inattentive          7          7      0.829      0.857      0.866       0.53
#               seatbelt         24         24      0.895      0.917      0.924      0.518
#             drowsiness         13         13      0.897          1      0.974      0.639
#               drinking          5          5      0.759          1      0.995      0.324
# Speed: 0.8ms preprocess, 3.7ms inference, 0.0ms loss, 1.1ms postprocess per image
# Results saved to runs/detect/val139
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client1/incremental_dataset/round_5/test/labels.cache... 42 images, 0 backgrounds, 0 corrupt: 100%|██████████| 42/42 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  7.02it/s]
#                    all         42         72      0.924      0.928      0.966       0.56
#            no_seatbelt         13         13      0.925      0.944      0.984      0.782
#                 mobile         10         10      0.982        0.9      0.978       0.41
#            inattentive          7          7      0.851      0.857      0.944      0.637
#               seatbelt         24         24      0.913      0.917      0.923      0.487
#             drowsiness         13         13      0.925       0.95      0.974      0.665
#               drinking          5          5      0.946          1      0.995      0.381
# Speed: 0.8ms preprocess, 1.5ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to runs/detect/val140
# Results for client2 - round_1:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_1/test/labels.cache... 12 images, 0 backgrounds, 0 corrupt: 100%|██████████| 12/12 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.48it/s]
#                    all         12         13      0.829        0.9      0.896       0.56
#            no_seatbelt          8          8      0.861          1      0.995      0.649
#                 mobile          5          5      0.796        0.8      0.797      0.471
# Speed: 0.1ms preprocess, 11.3ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val141
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_1/test/labels.cache... 12 images, 0 backgrounds, 0 corrupt: 100%|██████████| 12/12 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
#                    all         12         13      0.756        0.7      0.666      0.441
#            no_seatbelt          8          8      0.883          1      0.967      0.643
#                 mobile          5          5       0.63        0.4      0.364      0.239
# Speed: 0.1ms preprocess, 2.9ms inference, 0.0ms loss, 0.6ms postprocess per image
# Results saved to runs/detect/val142
# Results for client2 - round_2:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_2/test/labels.cache... 16 images, 0 backgrounds, 0 corrupt: 100%|██████████| 16/16 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.43it/s]
#                    all         16         18      0.956      0.935      0.949      0.679
#            no_seatbelt          8          8      0.942          1      0.995      0.781
#                 mobile          4          4          1      0.973      0.995      0.653
#            inattentive          6          6      0.927      0.833      0.856      0.601
# Speed: 0.1ms preprocess, 6.9ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val143
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_2/test/labels.cache... 16 images, 0 backgrounds, 0 corrupt: 100%|██████████| 16/16 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
#                    all         16         18      0.909      0.957      0.962      0.647
#            no_seatbelt          8          8      0.932          1      0.995      0.802
#                 mobile          4          4      0.795      0.974      0.895      0.521
#            inattentive          6          6          1      0.898      0.995      0.618
# Speed: 0.7ms preprocess, 3.1ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/val144
# Results for client2 - round_3:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_3/test/labels.cache... 25 images, 0 backgrounds, 0 corrupt: 100%|██████████| 25/25 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.87it/s]
#                    all         25         28      0.885      0.982       0.96      0.591
#            no_seatbelt          7          7      0.863          1      0.906      0.581
#                 mobile          2          2      0.861          1      0.995      0.509
#            inattentive          5          5      0.833          1      0.962      0.571
#               seatbelt         14         14      0.981      0.929      0.977      0.704
# Speed: 1.4ms preprocess, 6.5ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val145
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_3/test/labels.cache... 25 images, 0 backgrounds, 0 corrupt: 100%|██████████| 25/25 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.40it/s]
#                    all         25         28       0.87      0.952      0.954      0.622
#            no_seatbelt          7          7      0.863          1      0.889      0.533
#                 mobile          2          2      0.631          1      0.995        0.6
#            inattentive          5          5          1       0.88      0.995      0.677
#               seatbelt         14         14      0.985      0.929      0.938       0.68
# Speed: 2.2ms preprocess, 3.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val146
# Results for client2 - round_4:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_4/test/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.81it/s]
#                    all         26         35      0.626      0.599       0.66      0.424
#            no_seatbelt          7          7      0.737      0.857      0.918      0.575
#                 mobile          6          6      0.556        0.5      0.543      0.347
#            inattentive         10         10      0.879      0.729      0.869      0.439
#               seatbelt         11         11      0.958      0.909      0.971      0.757
#             drowsiness          1          1          0          0          0          0
# Speed: 1.4ms preprocess, 2.8ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val147
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_4/test/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  3.68it/s]
#                    all         26         35      0.665      0.626      0.691       0.44
#            no_seatbelt          7          7      0.779          1      0.995      0.692
#                 mobile          6          6      0.725       0.45      0.648      0.335
#            inattentive         10         10      0.885      0.771      0.822      0.426
#               seatbelt         11         11      0.934      0.909      0.988      0.744
#             drowsiness          1          1          0          0          0          0
# Speed: 2.0ms preprocess, 2.5ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val148
# Results for client2 - round_5:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_5/test/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.52it/s]
#                    all         26         35      0.806       0.87      0.828      0.484
#            no_seatbelt         14         14          1      0.975      0.995      0.711
#                 mobile          5          5      0.655        0.8      0.614      0.206
#            inattentive          5          5      0.476        0.6      0.541      0.274
#               seatbelt          8          8          1      0.977      0.995      0.671
#             drowsiness          3          3      0.898          1      0.995      0.557
# Speed: 1.3ms preprocess, 2.5ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to runs/detect/val149
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client2/incremental_dataset/round_5/test/labels.cache... 26 images, 0 backgrounds, 0 corrupt: 100%|██████████| 26/26 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  4.71it/s]
#                    all         26         35       0.84      0.798      0.838      0.517
#            no_seatbelt         14         14          1       0.98      0.995      0.695
#                 mobile          5          5      0.751      0.602      0.759      0.354
#            inattentive          5          5      0.523        0.6      0.479      0.178
#               seatbelt          8          8          1      0.808      0.962      0.706
#             drowsiness          3          3      0.928          1      0.995      0.653
# Speed: 1.3ms preprocess, 2.4ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val150
# Results for client3 - round_1:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_1/test/labels.cache... 27 images, 0 backgrounds, 0 corrupt: 100%|██████████| 27/27 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.60it/s]
#                    all         27         32      0.995          1      0.995      0.652
#            no_seatbelt         22         22      0.995          1      0.995      0.827
#                 mobile         10         10      0.994          1      0.995      0.477
# Speed: 0.7ms preprocess, 5.0ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/val151
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_1/test/labels.cache... 27 images, 0 backgrounds, 0 corrupt: 100%|██████████| 27/27 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  6.95it/s]
#                    all         27         32      0.993      0.997      0.995      0.653
#            no_seatbelt         22         22          1      0.994      0.995       0.84
#                 mobile         10         10      0.986          1      0.995      0.467
# Speed: 1.3ms preprocess, 2.2ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val152
# Results for client3 - round_2:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_2/test/labels.cache... 32 images, 0 backgrounds, 0 corrupt: 100%|██████████| 32/32 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.57it/s]
#                    all         32         40      0.943      0.935       0.95      0.635
#            no_seatbelt         18         18      0.993          1      0.995      0.785
#                 mobile          8          8      0.979      0.875      0.896      0.486
#            inattentive         14         14      0.858      0.929      0.958      0.633
# Speed: 0.5ms preprocess, 1.5ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to runs/detect/val153
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_2/test/labels.cache... 32 images, 0 backgrounds, 0 corrupt: 100%|██████████| 32/32 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 2/2 [00:00<00:00,  5.76it/s]
#                    all         32         40      0.958      0.935      0.952      0.632
#            no_seatbelt         18         18      0.983          1      0.995      0.821
#                 mobile          8          8       0.99      0.875      0.883      0.423
#            inattentive         14         14      0.901      0.929      0.979       0.65
# Speed: 0.5ms preprocess, 1.6ms inference, 0.1ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val154
# Results for client3 - round_3:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_3/test/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100%|██████████| 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.05it/s]
#                    all         46         63      0.947      0.997      0.984      0.738
#            no_seatbelt         29         29          1      0.988      0.995      0.827
#                 mobile          7          7      0.991          1      0.995      0.574
#            inattentive         10         10      0.827          1       0.95      0.696
#               seatbelt         17         17       0.97          1      0.995      0.855
# Speed: 0.8ms preprocess, 3.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val155
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_3/test/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100%|██████████| 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.58it/s]
#                    all         46         63      0.918      0.998      0.947      0.736
#            no_seatbelt         29         29      0.994          1      0.995      0.823
#                 mobile          7          7      0.862          1      0.889      0.543
#            inattentive         10         10      0.832      0.992      0.908       0.69
#               seatbelt         17         17      0.986          1      0.995      0.888
# Speed: 0.8ms preprocess, 1.5ms inference, 0.0ms loss, 3.2ms postprocess per image
# Results saved to runs/detect/val156
# Results for client3 - round_4:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_4/test/labels.cache... 45 images, 0 backgrounds, 0 corrupt: 100%|██████████| 45/45 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  5.99it/s]
#                    all         45         71      0.978       0.95      0.985      0.658
#            no_seatbelt         20         20      0.985          1      0.995      0.838
#                 mobile         15         15      0.997          1      0.995      0.419
#            inattentive          8          8      0.974          1      0.995      0.613
#               seatbelt         24         24      0.993          1      0.995       0.77
#             drowsiness          4          4      0.939       0.75      0.945      0.649
# Speed: 0.8ms preprocess, 3.7ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val157
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_4/test/labels.cache... 45 images, 0 backgrounds, 0 corrupt: 100%|██████████| 45/45 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.61it/s]
#                    all         45         71      0.949      0.893      0.934      0.634
#            no_seatbelt         20         20      0.994          1      0.995      0.826
#                 mobile         15         15      0.926      0.841      0.961      0.397
#            inattentive          8          8      0.889      0.875      0.971      0.611
#               seatbelt         24         24      0.991          1      0.995      0.788
#             drowsiness          4          4      0.945       0.75      0.749       0.55
# Speed: 0.7ms preprocess, 1.6ms inference, 0.0ms loss, 2.9ms postprocess per image
# Results saved to runs/detect/val158
# Results for client3 - round_5:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_5/test/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100%|██████████| 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.21it/s]
#                    all         46         86      0.932      0.959      0.969      0.651
#            no_seatbelt         24         24      0.968          1      0.995      0.852
#                 mobile         11         11      0.939          1      0.995      0.374
#            inattentive         12         12      0.762      0.833      0.838      0.574
#               seatbelt         20         20      0.962          1      0.995      0.809
#             drowsiness          6          6          1      0.923      0.995      0.702
#               drinking         13         13       0.96          1      0.995      0.595
# Speed: 0.6ms preprocess, 4.1ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs/detect/val159
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client3/incremental_dataset/round_5/test/labels.cache... 46 images, 0 backgrounds, 0 corrupt: 100%|██████████| 46/46 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.35it/s]
#                    all         46         86      0.958      0.933      0.962      0.661
#            no_seatbelt         24         24      0.983          1      0.995      0.851
#                 mobile         11         11          1      0.884      0.906      0.389
#            inattentive         12         12      0.794       0.75      0.885      0.588
#               seatbelt         20         20      0.982          1      0.995      0.847
#             drowsiness          6          6      0.989          1      0.995      0.707
#               drinking         13         13          1      0.963      0.995      0.585
# Speed: 0.7ms preprocess, 1.6ms inference, 0.0ms loss, 3.4ms postprocess per image
# Results saved to runs/detect/val160
# Results for client4 - round_1:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_1/test/labels.cache... 36 images, 0 backgrounds, 0 corrupt: 100%|██████████| 36/36 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.75it/s]
#                    all         36         42      0.996      0.999      0.995       0.68
#            no_seatbelt         28         28          1      0.997      0.995       0.83
#                 mobile         14         14      0.992          1      0.995      0.529
# Speed: 0.9ms preprocess, 4.5ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val161
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,840,918 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_1/test/labels.cache... 36 images, 0 backgrounds, 0 corrupt: 100%|██████████| 36/36 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  7.80it/s]
#                    all         36         42      0.996      0.986      0.995       0.71
#            no_seatbelt         28         28          1      0.971      0.995      0.838
#                 mobile         14         14      0.993          1      0.995      0.581
# Speed: 0.9ms preprocess, 1.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/val162
# Results for client4 - round_2:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_2/test/labels.cache... 39 images, 0 backgrounds, 0 corrupt: 100%|██████████| 39/39 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  6.27it/s]
#                    all         39         50      0.969      0.982      0.993      0.692
#            no_seatbelt         21         21      0.988          1      0.995      0.787
#                 mobile         16         16          1      0.947      0.995      0.553
#            inattentive         13         13      0.919          1       0.99      0.735
# Speed: 0.5ms preprocess, 4.4ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val163
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,841,497 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_2/test/labels.cache... 39 images, 0 backgrounds, 0 corrupt: 100%|██████████| 39/39 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 3/3 [00:00<00:00,  7.52it/s]
#                    all         39         50      0.957      0.968       0.99      0.687
#            no_seatbelt         21         21      0.989          1      0.995      0.797
#                 mobile         16         16          1       0.98      0.995      0.549
#            inattentive         13         13      0.881      0.923       0.98      0.715
# Speed: 0.8ms preprocess, 2.9ms inference, 0.0ms loss, 1.8ms postprocess per image
# Results saved to runs/detect/val164
# Results for client4 - round_3:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_3/test/labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  7.31it/s]
#                    all         59         74      0.958      0.947       0.98      0.751
#            no_seatbelt         29         29      0.967          1      0.991      0.876
#                 mobile         11         11      0.877          1      0.995      0.573
#            inattentive          5          5          1      0.787      0.938      0.824
#               seatbelt         29         29       0.99          1      0.995      0.732
# Speed: 0.9ms preprocess, 2.5ms inference, 0.0ms loss, 1.3ms postprocess per image
# Results saved to runs/detect/val165
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,076 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_3/test/labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  8.61it/s]
#                    all         59         74      0.952      0.997      0.995      0.777
#            no_seatbelt         29         29      0.945          1      0.993       0.84
#                 mobile         11         11      0.879          1      0.995      0.627
#            inattentive          5          5      0.985          1      0.995      0.834
#               seatbelt         29         29          1      0.987      0.995      0.808
# Speed: 0.7ms preprocess, 1.6ms inference, 0.0ms loss, 2.0ms postprocess per image
# Results saved to runs/detect/val166
# Results for client4 - round_4:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_4/test/labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  7.17it/s]
#                    all         59         96      0.986       0.91      0.961      0.703
#            no_seatbelt         29         29      0.963          1      0.965      0.775
#                 mobile         15         15      0.993      0.933      0.991      0.525
#            inattentive          4          4      0.973       0.75      0.888       0.71
#               seatbelt         27         27          1          1      0.995      0.773
#             drowsiness         20         21          1      0.868      0.968      0.732
# Speed: 0.9ms preprocess, 4.0ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to runs/detect/val167
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_4/test/labels.cache... 59 images, 0 backgrounds, 0 corrupt: 100%|██████████| 59/59 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.99it/s]
#                    all         59         96      0.983      0.946      0.973      0.716
#            no_seatbelt         29         29      0.959          1      0.971      0.795
#                 mobile         15         15      0.969      0.867      0.932      0.488
#            inattentive          4          4          1      0.988      0.995       0.76
#               seatbelt         27         27      0.986          1      0.995      0.778
#             drowsiness         20         21          1      0.877       0.97       0.76
# Speed: 0.8ms preprocess, 1.8ms inference, 0.1ms loss, 3.2ms postprocess per image
# Results saved to runs/detect/val168
# Results for client4 - round_5:
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_5/test/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.39it/s]
#                    all         62        120      0.949      0.949      0.966      0.687
#            no_seatbelt         21         21      0.948          1      0.986       0.78
#                 mobile         16         16      0.993          1      0.995      0.549
#            inattentive          7          7      0.774          1      0.933      0.632
#               seatbelt         38         38          1      0.976      0.995      0.777
#             drowsiness         15         16          1      0.717       0.89      0.651
#               drinking         22         22      0.981          1      0.995      0.732
# Speed: 0.7ms preprocess, 3.4ms inference, 0.0ms loss, 1.6ms postprocess per image
# Results saved to runs/detect/val169
# Ultralytics 8.3.72 🚀 Python-3.12.4 torch-2.3.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4090, 24210MiB)
# Model summary (fused): 218 layers, 25,843,234 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /home/u55hy/Documents/Research/safe-drive-fed-inc/client4/incremental_dataset/round_5/test/labels.cache... 62 images, 0 backgrounds, 0 corrupt: 100%|██████████| 62/62 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 4/4 [00:00<00:00,  6.48it/s]
#                    all         62        120      0.962      0.957      0.981      0.696
#            no_seatbelt         21         21      0.949          1      0.978      0.774
#                 mobile         16         16      0.996          1      0.995      0.539
#            inattentive          7          7      0.828          1      0.978      0.671
#               seatbelt         38         38          1      0.977      0.995       0.78
#             drowsiness         15         16          1      0.822      0.944      0.687
#               drinking         22         22          1      0.944      0.995      0.727
# Speed: 0.7ms preprocess, 1.6ms inference, 0.0ms loss, 2.3ms postprocess per image
# Results saved to runs/detect/val170

# %% [markdown]
# # Inference

# %%
device_folders = ['server', 'client1', 'client2', 'client3', 'client4']
incr_rounds = ['round_1', 'round_2', 'round_3', 'round_4', 'round_5']

for device in device_folders:
    model = YOLO()
    for round in incr_rounds:
        if device == 'server':
            model = YOLO(f'../runs/detect/{round}/weights/best.pt')
        else:
            model = YOLO(f'../runs/detect/{round}_fed12345_fine_tune_{device}/weights/best.pt')
        test_path = f'../{device}/incremental_dataset/{round}/test/images'
        for filename in os.listdir(test_path):
            img_path = os.path.join(test_path, filename)
            results = model(img_path)
            for result in results:
                boxes = result.boxes  # Boxes object for bounding box outputs
                masks = result.masks  # Masks object for segmentation masks outputs
                keypoints = result.keypoints  # Keypoints object for pose outputs
                probs = result.probs  # Probs object for classification outputs
                obb = result.obb  # Oriented boxes object for OBB outputs
                os.makedirs(f'inference/{device}/{round}', exist_ok=True)
                save_path = f'inference/{device}/{round}/{filename}'
                print(save_path)
                result.save(filename=f'{save_path}')
# Out:
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0253_jpg.rf.d702cef832862cd26fcb8de156da890c.jpg: 640x384 1 mobile, 3.1ms
# Speed: 17.8ms preprocess, 3.1ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0253_jpg.rf.d702cef832862cd26fcb8de156da890c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0116_jpg.rf.dbb05a973db86b76b93e5be445971ea2.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0116_jpg.rf.dbb05a973db86b76b93e5be445971ea2.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_1890_jpg.rf.db9da34ad645144c7f04884d4d1e10bf.jpg: 640x384 2 mobiles, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_1890_jpg.rf.db9da34ad645144c7f04884d4d1e10bf.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0229_jpg.rf.92a6e3d8c555baa998f715d11f71e964.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0229_jpg.rf.92a6e3d8c555baa998f715d11f71e964.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0076_jpg.rf.b474aba2105f4e08cefdbb72703c5dfc.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0076_jpg.rf.b474aba2105f4e08cefdbb72703c5dfc.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_4770_jpg.rf.1970b77861404284308949252712b1cb.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_4770_jpg.rf.1970b77861404284308949252712b1cb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0051_jpg.rf.27a58b40607c7736d7bae7b1986deaf4.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0051_jpg.rf.27a58b40607c7736d7bae7b1986deaf4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_5940_jpg.rf.fb90171a9ab5c50af63c5b45b3a44587.jpg: 640x384 1 no_seatbelt, 3.2ms
# Speed: 0.7ms preprocess, 3.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_5940_jpg.rf.fb90171a9ab5c50af63c5b45b3a44587.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0115_jpg.rf.4d8bfb63599ca6cef0b2272572aee531.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0115_jpg.rf.4d8bfb63599ca6cef0b2272572aee531.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_3960_jpg.rf.b0459cef528528af97394b0646873450.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_3960_jpg.rf.b0459cef528528af97394b0646873450.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0089_jpg.rf.7e26e4c367d765379b959d643b03a5f4.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0089_jpg.rf.7e26e4c367d765379b959d643b03a5f4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_6660_jpg.rf.46d61729c134cfa0c159c469962100fb.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_6660_jpg.rf.46d61729c134cfa0c159c469962100fb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_6720_jpg.rf.76832265fe4740b0944e35e295518619.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_6720_jpg.rf.76832265fe4740b0944e35e295518619.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0230_jpg.rf.e100d40bb050f70c9b73efa2f0255882.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0230_jpg.rf.e100d40bb050f70c9b73efa2f0255882.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_7260_jpg.rf.4a60072ddf7ae57f5225bb28af6decfb.jpg: 640x384 1 no_seatbelt, 2.7ms
# Speed: 0.7ms preprocess, 2.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_7260_jpg.rf.4a60072ddf7ae57f5225bb28af6decfb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0243_jpg.rf.fba4ff885db02faf42bd26c1b1622252.jpg: 640x384 1 mobile, 2.7ms
# Speed: 0.7ms preprocess, 2.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0243_jpg.rf.fba4ff885db02faf42bd26c1b1622252.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0113_jpg.rf.e447b86345b49aa902afb84dda2aff2e.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0113_jpg.rf.e447b86345b49aa902afb84dda2aff2e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0217_jpg.rf.03f48b64a592b08b37e47c2aafe500f9.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0217_jpg.rf.03f48b64a592b08b37e47c2aafe500f9.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0034_jpg.rf.a23a271c9e7b07698e0acc38c453ae00.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0034_jpg.rf.a23a271c9e7b07698e0acc38c453ae00.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0016_jpg.rf.cf58cc3126fbd2a91da9eeefca2af9a2.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0016_jpg.rf.cf58cc3126fbd2a91da9eeefca2af9a2.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0077_jpg.rf.34c4e26a1d5cac1e6d81f3160f935f0b.jpg: 640x384 1 no_seatbelt, 1 mobile, 4.6ms
# Speed: 1.2ms preprocess, 4.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0077_jpg.rf.34c4e26a1d5cac1e6d81f3160f935f0b.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0052_jpg.rf.30d6b5ed3dcd2d65c78c8fe638281c8d.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0052_jpg.rf.30d6b5ed3dcd2d65c78c8fe638281c8d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0021_jpg.rf.c6a1dde852cdd036456e0f95c50e6947.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0021_jpg.rf.c6a1dde852cdd036456e0f95c50e6947.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_4410_jpg.rf.433c5fbd683e81325aab48a42051fde0.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_4410_jpg.rf.433c5fbd683e81325aab48a42051fde0.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0233_jpg.rf.a3232bf844c7a076e24d92f60ba3039a.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0233_jpg.rf.a3232bf844c7a076e24d92f60ba3039a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0098_jpg.rf.008f3d0f41f66cc7f70801d87a5e300d.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0098_jpg.rf.008f3d0f41f66cc7f70801d87a5e300d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0237_jpg.rf.bce5f90b8117527ed45e430b4bd5cd18.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0237_jpg.rf.bce5f90b8117527ed45e430b4bd5cd18.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0124_jpg.rf.f22e0dab167579f7558b9563caf09882.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0124_jpg.rf.f22e0dab167579f7558b9563caf09882.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0007_jpg.rf.e235605050685fa9a62fd6dd44701a58.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0007_jpg.rf.e235605050685fa9a62fd6dd44701a58.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0103_jpg.rf.143f6e04293c79bc826c0679319162e4.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0103_jpg.rf.143f6e04293c79bc826c0679319162e4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0068_jpg.rf.7f7fe5b150ed2a7f8f584a142e5c852e.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0068_jpg.rf.7f7fe5b150ed2a7f8f584a142e5c852e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0224_jpg.rf.88dee993a8684abe9014b1b53c9cd294.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0224_jpg.rf.88dee993a8684abe9014b1b53c9cd294.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0234_jpg.rf.d7b25a2bf7a6f75d62e01b2f11059f18.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0234_jpg.rf.d7b25a2bf7a6f75d62e01b2f11059f18.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_4590_jpg.rf.62ccb836ea138431fc8af1fd3ad89454.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_4590_jpg.rf.62ccb836ea138431fc8af1fd3ad89454.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_5670_jpg.rf.1fc42d7566fcc34432cf23bd5d4c70ac.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_5670_jpg.rf.1fc42d7566fcc34432cf23bd5d4c70ac.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_3930_jpg.rf.dbafe5517380cdef263c51f7018f9d24.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_3930_jpg.rf.dbafe5517380cdef263c51f7018f9d24.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0122_jpg.rf.71ad1bbd53e1662ae2d49382e203fa7a.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0122_jpg.rf.71ad1bbd53e1662ae2d49382e203fa7a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_7020_jpg.rf.14798aa59e677903009aa348061d2a4c.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_7020_jpg.rf.14798aa59e677903009aa348061d2a4c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_5310_jpg.rf.e838f225c2acb24c01b8bded7a227d4c.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_5310_jpg.rf.e838f225c2acb24c01b8bded7a227d4c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0240_jpg.rf.7611765de8499553d65fd44b8129aef6.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0240_jpg.rf.7611765de8499553d65fd44b8129aef6.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_7380_jpg.rf.2f93d31c6c6d4a1cffa9a09e6ea8c2f0.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_7380_jpg.rf.2f93d31c6c6d4a1cffa9a09e6ea8c2f0.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_1_mp4-0028_jpg.rf.ab00da1939469baecb8454ca425d4ec7.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_1_mp4-0028_jpg.rf.ab00da1939469baecb8454ca425d4ec7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0057_jpg.rf.58c1a721c3ca9bc2f6f43c1d4d16af7c.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0057_jpg.rf.58c1a721c3ca9bc2f6f43c1d4d16af7c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/img_4650_jpg.rf.fea789ee98dc4c0a1dd0156f13a65173.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/img_4650_jpg.rf.fea789ee98dc4c0a1dd0156f13a65173.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_1/test/images/Server_2_mp4-0118_jpg.rf.629895059c081e79fdde9d85120367d7.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_1/Server_2_mp4-0118_jpg.rf.629895059c081e79fdde9d85120367d7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0024_jpg.rf.c309194f25bc0ab614b508ebb527147c.jpg: 640x384 1 no_seatbelt, 1 inattentive, 3.2ms
# Speed: 1.1ms preprocess, 3.2ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0024_jpg.rf.c309194f25bc0ab614b508ebb527147c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0144_jpg.rf.88542a9edbea48635e9aa36503ab7a23.jpg: 640x384 1 no_seatbelt, 2.9ms
# Speed: 1.1ms preprocess, 2.9ms inference, 5.7ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0144_jpg.rf.88542a9edbea48635e9aa36503ab7a23.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_2430_jpg.rf.050a51a9015cb19eb25f559c24d6b97d.jpg: 640x384 1 mobile, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_2430_jpg.rf.050a51a9015cb19eb25f559c24d6b97d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_5880_jpg.rf.c34a8c5477dc9b9669b587bd24c1580a.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_5880_jpg.rf.c34a8c5477dc9b9669b587bd24c1580a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0125_jpg.rf.66f75dc4f49bd1185177532324bf70c7.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0125_jpg.rf.66f75dc4f49bd1185177532324bf70c7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0086_jpg.rf.809807aba559fd684cc418846896536e.jpg: 640x384 1 no_seatbelt, 2 mobiles, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0086_jpg.rf.809807aba559fd684cc418846896536e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0023_jpg.rf.f250b5d9088cf5973342d3839fdff006.jpg: 640x384 1 no_seatbelt, 1 inattentive, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0023_jpg.rf.f250b5d9088cf5973342d3839fdff006.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_2490_jpg.rf.ee59a4ef42f26cb4afafcce08a7f4313.jpg: 640x384 1 mobile, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_2490_jpg.rf.ee59a4ef42f26cb4afafcce08a7f4313.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0115_jpg.rf.3c40e1a151e555b2bb86e7e35b93d29a.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0115_jpg.rf.3c40e1a151e555b2bb86e7e35b93d29a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0237_jpg.rf.ac15442057a0a1d280e12b522b48024f.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0237_jpg.rf.ac15442057a0a1d280e12b522b48024f.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_240_jpg.rf.34a4e365339ead964ce878f7241ec5bb.jpg: 640x384 1 inattentive, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_240_jpg.rf.34a4e365339ead964ce878f7241ec5bb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0074_jpg.rf.bbc0e9c3e627a3fbf1678764644434ee.jpg: 640x384 1 no_seatbelt, 1 mobile, 1 inattentive, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0074_jpg.rf.bbc0e9c3e627a3fbf1678764644434ee.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_2310_jpg.rf.58f52f51785b070274553312a99a6a41.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_2310_jpg.rf.58f52f51785b070274553312a99a6a41.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_7140_jpg.rf.a017d9a98ac9d41fc2949489b285efaa.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_7140_jpg.rf.a017d9a98ac9d41fc2949489b285efaa.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0032_jpg.rf.f7553404dcb38b01e0d9b1a631cc55f1.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0032_jpg.rf.f7553404dcb38b01e0d9b1a631cc55f1.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_2190_jpg.rf.2f071bf8e6ebe5e98ee839f6438a635d.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_2190_jpg.rf.2f071bf8e6ebe5e98ee839f6438a635d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0234_jpg.rf.e43862ce90dcc851c666150ff64ef83f.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0234_jpg.rf.e43862ce90dcc851c666150ff64ef83f.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_4140_jpg.rf.e7fb14a8b9aa078ded6a51c820f07d76.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_4140_jpg.rf.e7fb14a8b9aa078ded6a51c820f07d76.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0244_jpg.rf.99d5a03e3ec035bc3a6dfc58f0b83765.jpg: 640x384 2 mobiles, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0244_jpg.rf.99d5a03e3ec035bc3a6dfc58f0b83765.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_4440_jpg.rf.4400586f8b641abebdeda480374b55c0.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_4440_jpg.rf.4400586f8b641abebdeda480374b55c0.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0140_jpg.rf.981a8f7b22e0698a9178f90d268627ff.jpg: 640x384 1 inattentive, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0140_jpg.rf.981a8f7b22e0698a9178f90d268627ff.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0284_jpg.rf.e8fbcbfc31a2702a0fc9a586e0d32ae4.jpg: 640x384 (no detections), 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0284_jpg.rf.e8fbcbfc31a2702a0fc9a586e0d32ae4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0104_jpg.rf.6a77d947738cd876ff24bfc67126b5d4.jpg: 640x384 1 no_seatbelt, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0104_jpg.rf.6a77d947738cd876ff24bfc67126b5d4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_3900_jpg.rf.5c022786f2a1330048d34de4af25f353.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_3900_jpg.rf.5c022786f2a1330048d34de4af25f353.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0133_jpg.rf.739b25a5749f81becaedd0b37409b94c.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0133_jpg.rf.739b25a5749f81becaedd0b37409b94c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0161_jpg.rf.edb2b29d940959df31c68604ced062e8.jpg: 640x384 1 inattentive, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0161_jpg.rf.edb2b29d940959df31c68604ced062e8.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0069_jpg.rf.8f7d971b01a352061da0fab68be2f08a.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0069_jpg.rf.8f7d971b01a352061da0fab68be2f08a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_6030_jpg.rf.8e91e629e2ead22b36470cb9a3fd9b77.jpg: 640x384 1 inattentive, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_6030_jpg.rf.8e91e629e2ead22b36470cb9a3fd9b77.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0227_jpg.rf.ac35be44f4e8b227ef917242a07ee9a1.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0227_jpg.rf.ac35be44f4e8b227ef917242a07ee9a1.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0075_jpg.rf.3bb16f1f64cd6783ecffcdd787c2e9fa.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0075_jpg.rf.3bb16f1f64cd6783ecffcdd787c2e9fa.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0081_jpg.rf.c6e68009642be86fe5a9b125430ca8c3.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0081_jpg.rf.c6e68009642be86fe5a9b125430ca8c3.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0250_jpg.rf.ebcd9731c843544dbbcb0b5c0e0b905d.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0250_jpg.rf.ebcd9731c843544dbbcb0b5c0e0b905d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0121_jpg.rf.84fbfe2201ea18cc9b6ebe90006d23c4.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0121_jpg.rf.84fbfe2201ea18cc9b6ebe90006d23c4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_600_jpg.rf.6757b511059a315d505a36094a249332.jpg: 640x384 1 inattentive, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_600_jpg.rf.6757b511059a315d505a36094a249332.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0103_jpg.rf.143f6e04293c79bc826c0679319162e4.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0103_jpg.rf.143f6e04293c79bc826c0679319162e4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0242_jpg.rf.d5033c2f1bd1a30feeb1b341afc5c244.jpg: 640x384 1 mobile, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0242_jpg.rf.d5033c2f1bd1a30feeb1b341afc5c244.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0101_jpg.rf.ba0e05284dee60555b8e56770049029e.jpg: 640x384 1 no_seatbelt, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0101_jpg.rf.ba0e05284dee60555b8e56770049029e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_2280_jpg.rf.0a8920d890792871e3c848bc754cdfc6.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_2280_jpg.rf.0a8920d890792871e3c848bc754cdfc6.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0027_jpg.rf.7106d7a63148b8a5802c115988c88227.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0027_jpg.rf.7106d7a63148b8a5802c115988c88227.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0227_jpg.rf.6007321126983ff18b31ee2fa4bad302.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0227_jpg.rf.6007321126983ff18b31ee2fa4bad302.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0232_jpg.rf.a623a481c405b61d2998aa374b714b25.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0232_jpg.rf.a623a481c405b61d2998aa374b714b25.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_4590_jpg.rf.62ccb836ea138431fc8af1fd3ad89454.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_4590_jpg.rf.62ccb836ea138431fc8af1fd3ad89454.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0165_jpg.rf.a79f9d56942a4dd4f9c2abc3a75cf30a.jpg: 640x384 1 inattentive, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0165_jpg.rf.a79f9d56942a4dd4f9c2abc3a75cf30a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_7020_jpg.rf.14798aa59e677903009aa348061d2a4c.jpg: 640x384 1 no_seatbelt, 1 inattentive, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_7020_jpg.rf.14798aa59e677903009aa348061d2a4c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_7470_jpg.rf.dd4e050de553fa2c4e28340459a3c0fa.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_7470_jpg.rf.dd4e050de553fa2c4e28340459a3c0fa.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0142_jpg.rf.b73648acc227c62ccb1cd3c673778a03.jpg: 640x384 1 inattentive, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0142_jpg.rf.b73648acc227c62ccb1cd3c673778a03.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_3690_jpg.rf.2802cb4e96fc0760c8ac9b0f6ee5d214.jpg: 640x384 1 mobile, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_3690_jpg.rf.2802cb4e96fc0760c8ac9b0f6ee5d214.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/img_6270_jpg.rf.d9c17b0e29dc61833a031b9e4614ccad.jpg: 640x384 1 no_seatbelt, 1 inattentive, 2.8ms
# Speed: 1.0ms preprocess, 2.8ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/img_6270_jpg.rf.d9c17b0e29dc61833a031b9e4614ccad.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0057_jpg.rf.58c1a721c3ca9bc2f6f43c1d4d16af7c.jpg: 640x384 2 no_seatbelts, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0057_jpg.rf.58c1a721c3ca9bc2f6f43c1d4d16af7c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_1_mp4-0081_jpg.rf.24c9e0e0cf23fd3709c960f71342e2f9.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_1_mp4-0081_jpg.rf.24c9e0e0cf23fd3709c960f71342e2f9.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0106_jpg.rf.451006e84d49d31a371d8b3662d5732e.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0106_jpg.rf.451006e84d49d31a371d8b3662d5732e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_2/test/images/Server_2_mp4-0226_jpg.rf.a82a68acfb9a06c7244a383ad668b20e.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_2/Server_2_mp4-0226_jpg.rf.a82a68acfb9a06c7244a383ad668b20e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_7200_jpg.rf.1b2a7c2b7d42c96bbaf1fc758ea78384.jpg: 640x384 1 no_seatbelt, 1 inattentive, 3.0ms
# Speed: 0.8ms preprocess, 3.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_7200_jpg.rf.1b2a7c2b7d42c96bbaf1fc758ea78384.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0166_jpg.rf.77635058bee09ea7a27709e7e059ff59.jpg: 640x384 1 seatbelt, 2.9ms
# Speed: 0.8ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0166_jpg.rf.77635058bee09ea7a27709e7e059ff59.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0128_jpg.rf.e0a924d80f3ea2ce8bb71e90ed18c9b7.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0128_jpg.rf.e0a924d80f3ea2ce8bb71e90ed18c9b7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0095_jpg.rf.1f1108ed93de6a1cff73050a62b90ec9.jpg: 640x384 1 no_seatbelt, 1 mobile, 1 inattentive, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0095_jpg.rf.1f1108ed93de6a1cff73050a62b90ec9.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0156_jpg.rf.3b52cb6aa71f70ffaecebdb9612b410b.jpg: 640x384 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0156_jpg.rf.3b52cb6aa71f70ffaecebdb9612b410b.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0049_jpg.rf.0f4bcae6db97a1dba7a750338091aa03.jpg: 640x384 1 no_seatbelt, 2.9ms
# Speed: 0.9ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0049_jpg.rf.0f4bcae6db97a1dba7a750338091aa03.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0046_jpg.rf.d00aba4638c0b4b5805f2efd17d43b7d.jpg: 640x384 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0046_jpg.rf.d00aba4638c0b4b5805f2efd17d43b7d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0012_jpg.rf.87c4432556c1d2e86c45cbc53dd2a35e.jpg: 640x384 1 no_seatbelt, 1 inattentive, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0012_jpg.rf.87c4432556c1d2e86c45cbc53dd2a35e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0115_jpg.rf.3c40e1a151e555b2bb86e7e35b93d29a.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0115_jpg.rf.3c40e1a151e555b2bb86e7e35b93d29a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0115_jpg.rf.4d8bfb63599ca6cef0b2272572aee531.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0115_jpg.rf.4d8bfb63599ca6cef0b2272572aee531.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_1500_jpg.rf.b640bd38a1d554b6b4a2d3e5e179fa99.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_1500_jpg.rf.b640bd38a1d554b6b4a2d3e5e179fa99.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_2310_jpg.rf.58f52f51785b070274553312a99a6a41.jpg: 640x384 2 mobiles, 1 seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_2310_jpg.rf.58f52f51785b070274553312a99a6a41.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_1530_jpg.rf.24204baaef572ff1e1632ff5188ade32.jpg: 640x384 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_1530_jpg.rf.24204baaef572ff1e1632ff5188ade32.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0201_jpg.rf.2ca49d98a4ca0301196a9c762c222b61.jpg: 640x384 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0201_jpg.rf.2ca49d98a4ca0301196a9c762c222b61.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_2010_jpg.rf.fc36e8e3ae4783b6df51ea8ae2f702d5.jpg: 640x384 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_2010_jpg.rf.fc36e8e3ae4783b6df51ea8ae2f702d5.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0162_jpg.rf.d51fa2d0f0a0d47ac166f5e9d49496ee.jpg: 640x384 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0162_jpg.rf.d51fa2d0f0a0d47ac166f5e9d49496ee.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_2370_jpg.rf.fb4da6a3fbbf80427c32a061d957882f.jpg: 640x384 1 mobile, 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_2370_jpg.rf.fb4da6a3fbbf80427c32a061d957882f.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_1080_jpg.rf.e5d81106a00808f763902310a136f76e.jpg: 640x384 1 seatbelt, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_1080_jpg.rf.e5d81106a00808f763902310a136f76e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0274_jpg.rf.a9925f12be5fad39ac6db2db3bc77ea7.jpg: 640x384 1 seatbelt, 3.4ms
# Speed: 1.4ms preprocess, 3.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0274_jpg.rf.a9925f12be5fad39ac6db2db3bc77ea7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0248_jpg.rf.ce82f2e2520e225d0a50dd7c117096ad.jpg: 640x384 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0248_jpg.rf.ce82f2e2520e225d0a50dd7c117096ad.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_1_mp4-0160_jpg.rf.424d22dcab88e8c0b9230cdc7135f5b5.jpg: 640x384 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.9ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_1_mp4-0160_jpg.rf.424d22dcab88e8c0b9230cdc7135f5b5.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_4110_jpg.rf.ce4408153a8f0203536b979a74197fe7.jpg: 640x384 (no detections), 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_4110_jpg.rf.ce4408153a8f0203536b979a74197fe7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0207_jpg.rf.e06682850adb8d732b38747292d443ed.jpg: 640x384 1 seatbelt, 2.9ms
# Speed: 1.0ms preprocess, 2.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0207_jpg.rf.e06682850adb8d732b38747292d443ed.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0230_jpg.rf.e100d40bb050f70c9b73efa2f0255882.jpg: 640x384 1 mobile, 2 seatbelts, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0230_jpg.rf.e100d40bb050f70c9b73efa2f0255882.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/Server_2_mp4-0223_jpg.rf.0521bcbfff104b27729f48e12a109059.jpg: 640x384 1 mobile, 1 seatbelt, 3.3ms
# Speed: 0.8ms preprocess, 3.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/Server_2_mp4-0223_jpg.rf.0521bcbfff104b27729f48e12a109059.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../server/incremental_dataset/round_3/test/images/img_810_jpg.rf.d05eaaedc3360b7fb8a938fa0c566fc0.jpg: 640x384 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/server/round_3/img_810_jpg.rf.d05eaaedc3360b7fb8a938fa0c566fc0.jpg
#
# ...
# inference/client4/round_5/Img-3937_mp4-0569_jpg.rf.b0983feb850b89ab03f02124d394cfe7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0160_jpg.rf.6576566ee0662d1111f197baed622e5e.jpg: 640x384 1 no_seatbelt, 1 drinking, 2.7ms
# Speed: 0.7ms preprocess, 2.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0160_jpg.rf.6576566ee0662d1111f197baed622e5e.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0557_jpg.rf.fa112b7facc7c64093297e3045d56006.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0557_jpg.rf.fa112b7facc7c64093297e3045d56006.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0575_jpg.rf.f5e986079d09dbe44e410f9369972f3a.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0575_jpg.rf.f5e986079d09dbe44e410f9369972f3a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0704_jpg.rf.3f2da5ac05c50c4565b0f9d8fad896c4.jpg: 640x384 1 mobile, 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0704_jpg.rf.3f2da5ac05c50c4565b0f9d8fad896c4.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0706_jpg.rf.357f3b4960cec29b600b551aaf16f2e6.jpg: 640x384 1 mobile, 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0706_jpg.rf.357f3b4960cec29b600b551aaf16f2e6.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0052_jpg.rf.b4983b948f043f89c4d37db79745c28d.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0052_jpg.rf.b4983b948f043f89c4d37db79745c28d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0604_jpg.rf.23319aeda70abd7b8b97d68d5839a9b2.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0604_jpg.rf.23319aeda70abd7b8b97d68d5839a9b2.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0075_jpg.rf.e8ecee00dfdb2613ba71c16e3195b491.jpg: 640x384 1 no_seatbelt, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0075_jpg.rf.e8ecee00dfdb2613ba71c16e3195b491.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0658_jpg.rf.b3d1f045b00a1391f15e34cf4b29b46c.jpg: 640x384 1 seatbelt, 1 drowsiness, 5.5ms
# Speed: 1.2ms preprocess, 5.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0658_jpg.rf.b3d1f045b00a1391f15e34cf4b29b46c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0320_jpg.rf.6b9515ffcf6a6ccc620e071c366cf47c.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0320_jpg.rf.6b9515ffcf6a6ccc620e071c366cf47c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0598_jpg.rf.47c4df50e704732c8a6ed5ab78624671.jpg: 640x384 1 seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0598_jpg.rf.47c4df50e704732c8a6ed5ab78624671.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0547_jpg.rf.58a6af1285dcbf81c161af7082deb39c.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0547_jpg.rf.58a6af1285dcbf81c161af7082deb39c.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0551_jpg.rf.5ad4c6bb993a8060261daf896df8ca0d.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0551_jpg.rf.5ad4c6bb993a8060261daf896df8ca0d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0373_jpg.rf.c0249b6bb09a12014701986090f32e8d.jpg: 640x384 1 seatbelt, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0373_jpg.rf.c0249b6bb09a12014701986090f32e8d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0562_jpg.rf.dbd927f186f48169fcff31dc105d7d1f.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0562_jpg.rf.dbd927f186f48169fcff31dc105d7d1f.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0553_jpg.rf.c721895398cf97755393184a96c59cec.jpg: 640x384 1 seatbelt, 1 drinking, 2.7ms
# Speed: 0.7ms preprocess, 2.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0553_jpg.rf.c721895398cf97755393184a96c59cec.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0215_jpg.rf.ff643a9c0a5b0d94378b4fc6525b47ee.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0215_jpg.rf.ff643a9c0a5b0d94378b4fc6525b47ee.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0055_jpg.rf.5a9a3a55103e54889350588dac21c40f.jpg: 640x384 1 no_seatbelt, 1 inattentive, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0055_jpg.rf.5a9a3a55103e54889350588dac21c40f.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0407_jpg.rf.ab4dedc3d8cc8f6933e606bfcafcb378.jpg: 640x384 1 inattentive, 1 seatbelt, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0407_jpg.rf.ab4dedc3d8cc8f6933e606bfcafcb378.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0504_jpg.rf.cb42f8cca900f7164aa161340e012780.jpg: 640x384 1 seatbelt, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0504_jpg.rf.cb42f8cca900f7164aa161340e012780.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0293_jpg.rf.1e5d39f840a3b697bc02686472ff7aeb.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0293_jpg.rf.1e5d39f840a3b697bc02686472ff7aeb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0781_jpg.rf.512e624a1ad9bc410fdfde4597f78f11.jpg: 640x384 1 mobile, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0781_jpg.rf.512e624a1ad9bc410fdfde4597f78f11.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0558_jpg.rf.3bcb71121c9df295df072ab3826df48b.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0558_jpg.rf.3bcb71121c9df295df072ab3826df48b.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0063_jpg.rf.3d90345f00f3c86f170c29916fe64ff3.jpg: 640x384 1 no_seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0063_jpg.rf.3d90345f00f3c86f170c29916fe64ff3.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0325_jpg.rf.8918d0842c0369710281c5f39960d415.jpg: 640x384 1 no_seatbelt, 1 mobile, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0325_jpg.rf.8918d0842c0369710281c5f39960d415.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0321_jpg.rf.e442132f8226a056ee4aba115b152117.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0321_jpg.rf.e442132f8226a056ee4aba115b152117.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0227_jpg.rf.72f2ffe8e93065c82bbe5816fa607fdb.jpg: 640x384 1 no_seatbelt, 1 drinking, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0227_jpg.rf.72f2ffe8e93065c82bbe5816fa607fdb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0275_jpg.rf.f788af09fa5f313e9ae5563970fb9bc0.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0275_jpg.rf.f788af09fa5f313e9ae5563970fb9bc0.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0738_jpg.rf.4a1a9710b4f2f3c851b470814fc8a2bb.jpg: 640x384 1 mobile, 1 seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0738_jpg.rf.4a1a9710b4f2f3c851b470814fc8a2bb.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0177_jpg.rf.dbbb2865801ed6cbc446c6c4062961a3.jpg: 640x384 1 no_seatbelt, 1 inattentive, 1 drinking, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0177_jpg.rf.dbbb2865801ed6cbc446c6c4062961a3.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0290_jpg.rf.43e7bc64e0a41ae2bc1ed7016c6b40c3.jpg: 640x384 1 no_seatbelt, 1 mobile, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0290_jpg.rf.43e7bc64e0a41ae2bc1ed7016c6b40c3.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0774_jpg.rf.97f139fa6e43027cc743a4bf39a00fda.jpg: 640x384 1 mobile, 1 seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0774_jpg.rf.97f139fa6e43027cc743a4bf39a00fda.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0326_jpg.rf.63dc1d7e861737e5a70588669e8d009d.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0326_jpg.rf.63dc1d7e861737e5a70588669e8d009d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0300_jpg.rf.aab45da54c5b259b23435aa3991da10a.jpg: 640x384 1 no_seatbelt, 1 mobile, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0300_jpg.rf.aab45da54c5b259b23435aa3991da10a.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0534_jpg.rf.6d97c43f4339f6a93a5ac4a6f18ca39d.jpg: 640x384 1 seatbelt, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0534_jpg.rf.6d97c43f4339f6a93a5ac4a6f18ca39d.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0647_jpg.rf.3b05cad06dd8632ce56dd4e04abd1131.jpg: 640x384 1 seatbelt, 1 drinking, 2.8ms
# Speed: 0.8ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0647_jpg.rf.3b05cad06dd8632ce56dd4e04abd1131.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0782_jpg.rf.c4f7defcc7fcedb9aff7eb1fa3410dc7.jpg: 640x384 1 seatbelt, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0782_jpg.rf.c4f7defcc7fcedb9aff7eb1fa3410dc7.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0669_jpg.rf.30679afb6b3552d9855a5217ad84c670.jpg: 640x384 1 mobile, 1 seatbelt, 1 drowsiness, 2.8ms
# Speed: 0.7ms preprocess, 2.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0669_jpg.rf.30679afb6b3552d9855a5217ad84c670.jpg
#
# image 1/1 /home/u55hy/Documents/Research/safe-drive-fed-inc/results/../client4/incremental_dataset/round_5/test/images/Img-3937_mp4-0652_jpg.rf.b80109a3aef6b8c0a1bf77f12e30c91c.jpg: 640x384 1 seatbelt, 1 drinking, 5.7ms
# Speed: 1.2ms preprocess, 5.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 384)
# inference/client4/round_5/Img-3937_mp4-0652_jpg.rf.b80109a3aef6b8c0a1bf77f12e30c91c.jpg
